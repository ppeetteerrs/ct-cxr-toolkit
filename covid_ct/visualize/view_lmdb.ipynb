# %%
import sys
sys.path.append("../../")

import numpy as np
from lib.plot import plot_grid
from lib.lmdb import LMDBImageReader
reader = LMDBImageReader("../output/covid_ct_lmdb")
print(reader.get_length())
print(reader.get_meta((600, "subject")))
plot_grid([np.array(reader.get_img((600, "soft")))])
# Out:
# 735
# 763
