# %%
import pyvista
import sys
sys.path.append("../../")

from lib.utils import load
from lib.dicom import read_dcm
from lib.plot import plot_grid
from lib.ct.drr import get_drr
from lib.cv import remove_border

pyvista.start_xvfb()

ct_paths = load("../output/ct_paths.pkl")
med_paths = ct_paths.iloc[0]["lung"]
med_sitk, med_np = read_dcm(med_paths, clip=True)
drr = get_drr(med_sitk, move_by=750, show=True)
# Out:
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /home/user/mambaforge/envs/user/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F4A2B2DEE80>

# %%
plot_grid([remove_border(drr, tol=0.3)])
