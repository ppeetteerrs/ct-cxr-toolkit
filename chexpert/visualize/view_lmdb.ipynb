# %%
import sys
sys.path.append("../../")

import numpy as np
from lib.plot import plot_grid
from lib.lmdb import LMDBImageReader
reader = LMDBImageReader("../output/lmdb")
plot_grid([np.array(reader.get_img(1000))])
