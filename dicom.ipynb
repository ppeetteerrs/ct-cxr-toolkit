# %%
import pandas as pd
from ct.utils import read_dcm, normalize_hu, min_max_normalize
import cv2 as cv
df = pd.read_pickle("output/covid_ct_train_meta.pkl").iloc[140]["med"]
img = normalize_hu(read_dcm(df)[1])[::60,:,:]
img = min_max_normalize(img)

# %%
for idx, i in enumerate(img):
    cv.imwrite(f"397_ct/{idx}.png", i)

# %%
import pickle
item = pickle.load(open("mapping.pkl", "rb"))

# %%
item["train"][405]
# Out:
# 140

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.mean(img, axis=1), cmap="gray")
